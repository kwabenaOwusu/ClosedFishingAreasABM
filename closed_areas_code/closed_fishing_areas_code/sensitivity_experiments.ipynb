# %%
### CARRYING CAPACITY ###

import shutil, os
import numpy as np
import pandas as pd
import math
import random
import statistics
import csv
import time as mytime
import itertools

numsim = 3  # number of replicates
start_time=mytime.time() # server time for starting

outfname  = os.path.join(os.getcwd(), 'carrying_capacity1' + '.csv')
with open(outfname,'w', newline="", buffering=1) as outfile:
    allsimdat=csv.writer(outfile)

    K = 2600 # carrying capacity of fishing ground
    val_range = [int(K-K*0.5), int(K+K*0.5)]
    for val in val_range:
        # K = 2600 # carrying capacity of fishing ground
        growth_prob = 0.693 # maximum intrinsic growth rate
        natural_mortality = 0.00183 # natural mortality 
        num_pirogue = 140 # number of pirogues 
        catchability = 0.5 # catchability of pirogues
        K = val 
    
        for rep in range(numsim):
            code_path = os.path.join(os.getcwd(), 'UPDATED_ABM_MPA.ipynb')
            # %run "{code_path }"
            with open(os.path.join(os.getcwd(), 'updated_simulation_data.csv'), 'r') as csvfile:
                onesimdat = csv.reader(csvfile, delimiter=',')
                header = next(onesimdat)
                header.extend(['sim_nr', 'para_value', 'para_type'])
                if all([rep == 0, val == 1300]):
                    allsimdat.writerow(header)
                for row in onesimdat:
                    row.extend([str(rep), str(val), 'carrying_capacity'])
                    allsimdat.writerow(row)
            print('Done, upwelling closure, simulation %i, carrying capacity value %.1f, ended at %s '%(rep+1, val,mytime.ctime()))

# %%
### MAXIMUM INTRINSIC GROWTH RATE ###

import shutil, os
import numpy as np
import pandas as pd
import math
import random
import statistics
import csv
import time as mytime
import itertools

numsim = 3  # number of replicates
start_time=mytime.time() # server time for starting

outfname  = os.path.join(os.getcwd(), 'growth_prob1' + '.csv')
with open(outfname,'w', newline="", buffering=1) as outfile:
    allsimdat=csv.writer(outfile)

    growth_prob = 0.693 # maximum intrinsic growth rate
    val_range = [growth_prob-growth_prob*0.5, growth_prob+growth_prob*0.5]
    for val in val_range:
        K = 2600 # carrying capacity of fishing ground
        # growth_prob = 0.693 # maximum intrinsic growth rate
        natural_mortality = 0.00183 # natural mortality 
        num_pirogue = 140 # number of pirogues 
        catchability = 0.5 # catchability of pirogues
        growth_prob = val 
    
        for rep in range(numsim):
            code_path = os.path.join(os.getcwd(), 'UPDATED_ABM_MPA.ipynb')
            # %run "{code_path }"
            with open(os.path.join(os.getcwd(), 'updated_simulation_data.csv'), 'r') as csvfile:
                onesimdat = csv.reader(csvfile, delimiter=',')
                header = next(onesimdat)
                header.extend(['sim_nr', 'para_value', 'para_type'])
                if all([rep == 0, val == 0.3465]):
                    allsimdat.writerow(header)
                for row in onesimdat:
                    row.extend([str(rep), str(val), 'growth_prob'])
                    allsimdat.writerow(row)
            print('Done, upwelling closure, simulation %i, growth_prob value %.4f, ended at %s '%(rep+1, val, mytime.ctime()))

# %%
### NATURAL PROBABILITY ###

import shutil, os
import numpy as np
import pandas as pd
import math
import random
import statistics
import csv
import time as mytime
import itertools

numsim = 3  # number of replicates
start_time=mytime.time() # server time for starting

outfname  = os.path.join(os.getcwd(), 'natural_mortality1' + '.csv')
with open(outfname,'w', newline="", buffering=1) as outfile:
    allsimdat=csv.writer(outfile)

    natural_mortality = 0.00183 # natural mortality 
    val_range = [natural_mortality-natural_mortality*0.5, natural_mortality+natural_mortality*0.5]
    for val in val_range:
        K = 2600 # carrying capacity of fishing ground
        growth_prob = 0.693 # maximum intrinsic growth rate
        # natural_mortality = 0.00183 # natural mortality 
        num_pirogue = 140 # number of pirogues 
        catchability = 0.5 # catchability of pirogues
        natural_mortality = val 
    
        for rep in range(numsim):
            code_path = os.path.join(os.getcwd(), 'UPDATED_ABM_MPA.ipynb')
            # %run "{code_path }"
            with open(os.path.join(os.getcwd(), 'updated_simulation_data.csv'), 'r') as csvfile:
                onesimdat = csv.reader(csvfile, delimiter=',')
                header = next(onesimdat)
                header.extend(['sim_nr', 'para_value', 'para_type'])
                if all([rep == 0, val == 0.000915]):
                    allsimdat.writerow(header)
                for row in onesimdat:
                    row.extend([str(rep), str(val), 'natural_mortality'])
                    allsimdat.writerow(row)
            print('Done, upwelling closure, simulation %i, natural_mortality value %.4f, ended at %s '%(rep+1, val, mytime.ctime()))

# %%
### NUMBER OF PIROGUE ###

import shutil, os
import numpy as np
import pandas as pd
import math
import random
import statistics
import csv
import time as mytime
import itertools

numsim = 3  # number of replicates
start_time=mytime.time() # server time for starting

outfname  = os.path.join(os.getcwd(), 'num_pirogue1' + '.csv')
with open(outfname,'w', newline="", buffering=1) as outfile:
    allsimdat=csv.writer(outfile)

    num_pirogue = 140 # number of pirogues 
    val_range = [int(num_pirogue-num_pirogue*0.5), int(num_pirogue+num_pirogue*0.5)]
    for val in val_range:
        K = 2600 # carrying capacity of fishing ground
        growth_prob = 0.693 # maximum intrinsic growth rate
        natural_mortality = 0.00183 # natural mortality 
        # num_pirogue = 140 # number of pirogues 
        catchability = 0.5 # catchability of pirogues
        num_pirogue  = val 
    
        for rep in range(numsim):
            code_path = os.path.join(os.getcwd(), 'UPDATED_ABM_MPA.ipynb')
            # %run "{code_path }"
            with open(os.path.join(os.getcwd(), 'updated_simulation_data.csv'), 'r') as csvfile:
                onesimdat = csv.reader(csvfile, delimiter=',')
                header = next(onesimdat)
                header.extend(['sim_nr', 'para_value', 'para_type'])
                if all([rep == 0, val == 70]):
                    allsimdat.writerow(header)
                for row in onesimdat:
                    row.extend([str(rep), str(val), 'num_pirogue'])
                    allsimdat.writerow(row)
            print('Done, upwelling closure, simulation %i,  num_pirogue value %.1f, ended at %s '%(rep+1, val, mytime.ctime()))

# %%
### CATCHABILITY ###

import shutil, os
import numpy as np
import pandas as pd
import math
import random
import statistics
import csv
import time as mytime
import itertools

numsim = 3  # number of replicates
start_time=mytime.time() # server time for starting

outfname  = os.path.join(os.getcwd(), 'catchability1' + '.csv')
with open(outfname,'w', newline="", buffering=1) as outfile:
    allsimdat=csv.writer(outfile)

    catchability = 0.5 # catchability of pirogues
    val_range = [catchability-catchability*0.5, catchability+catchability*0.5]
    for val in val_range:
        K = 2600 # carrying capacity of fishing ground
        growth_prob = 0.693 # maximum intrinsic growth rate
        natural_mortality = 0.00183 # natural mortality 
        num_pirogue = 140 # number of pirogues 
        # catchability = 0.5 # catchability of pirogues
        catchability  = val 
    
        for rep in range(numsim):
            code_path = os.path.join(os.getcwd(), 'UPDATED_ABM_MPA.ipynb')
            # %run "{code_path }"
            with open(os.path.join(os.getcwd(), 'updated_simulation_data.csv'), 'r') as csvfile:
                onesimdat = csv.reader(csvfile, delimiter=',')
                header = next(onesimdat)
                header.extend(['sim_nr', 'para_value', 'para_type'])
                if all([rep == 0, val == 0.25]):
                    allsimdat.writerow(header)
                for row in onesimdat:
                    row.extend([str(rep), str(val), 'catchability'])
                    allsimdat.writerow(row)
            print('Done, upwelling closure, simulation %i,  catchability value %.2f, ended at %s '%(rep+1, val, mytime.ctime()))
